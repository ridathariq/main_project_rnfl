# %%
import os
os.listdir(r"C:\Users\ridat\OneDrive\Desktop\Fundus")
# Out:
# ['.ipynb_checkpoints',
#  'dec_3.ipynb',
#  'dec_8.ipynb',
#  'Gaussian.ipynb',
#  'mean_zero_dce_output.png',
#  'retina.jpg',
#  'retina1.jpg',
#  'retina2.jpg',
#  'retina3.jpg',
#  'retina4.jpg',
#  'SAM.ipynb',
#  'sam2',
#  'SAM2.ipynb']

# %%
import os
print(os.path.exists("sam_vit_h.pth"))
# Out:
# False

# %%
import segment_anything
print("SAM package installed")
# Out:
# SAM package installed

# %%
from segment_anything import sam_model_registry, SamPredictor
print("SAM modules loaded")
# Out:
# SAM modules loaded

# %%
import torch
print(torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# 2.9.1+cpu
# CUDA available: False

# %%
sam = sam_model_registry["vit_h"](checkpoint="sam_vit_h.pth")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sam = sam_model_registry["vit_h"](checkpoint="sam_vit_h.pth")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\segment_anything\build_sam.py:15, in build_sam_vit_h(checkpoint)
#      14 def build_sam_vit_h(checkpoint=None):
# ---> 15     return _build_sam(
#      16         encoder_embed_dim=1280,
#      17         encoder_depth=32,
#      18         encoder_num_heads=16,
#      19         encoder_global_attn_indexes=[7, 15, 23, 31],
#      20         checkpoint=checkpoint,
#      21     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\segment_anything\build_sam.py:104, in _build_sam(encoder_embed_dim, encoder_depth, encoder_num_heads, encoder_global_attn_indexes, checkpoint)
#     102 sam.eval()
#     103 if checkpoint is not None:
# ...

# %%
from segment_anything import SamPredictor
print("SAM installed correctly")
# Out:
# SAM installed correctly

# %%
from segment_anything import sam_model_registry, SamPredictor
import torch

sam = sam_model_registry["vit_b"](
    checkpoint=r"C:\Users\ridat\OneDrive\Desktop\Fundus\sam_vit_b.pth"
)

device = "cuda" if torch.cuda.is_available() else "cpu"
sam.to(device)

predictor = SamPredictor(sam)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 from segment_anything import sam_model_registry, SamPredictor
#       2 import torch
# ----> 4 sam = sam_model_registry["vit_b"](
#       5     checkpoint=r"C:\Users\ridat\OneDrive\Desktop\Fundus\sam_vit_b.pth"
#       6 )
#       8 device = "cuda" if torch.cuda.is_available() else "cpu"
#       9 sam.to(device)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\segment_anything\build_sam.py:38, in build_sam_vit_b(checkpoint)
#      37 def build_sam_vit_b(checkpoint=None):
# ---> 38     return _build_sam(
#      39         encoder_embed_dim=768,
#      40         encoder_depth=12,
#      41         encoder_num_heads=12,
#      42         encoder_global_attn_indexes=[2, 5, 8, 11],
#      43         checkpoint=checkpoint,
#      44     )
#
# ...

# %%
import os
print(os.path.exists(r"C:\Users\ridat\OneDrive\Desktop\Fundus\sam_vit_b.pth"))
# Out:
# True
